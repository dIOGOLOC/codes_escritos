# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import obspy
import os
from obspy.taup import TauPyModel
from obspy.geodetics import kilometer2degrees
import copy
import matplotlib
from matplotlib.cm import get_cmap
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.basemap import Basemap
import shapefile
from fatiando import gridder, utils
import scipy.io
import matplotlib.cm as cm
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# %% [markdown]
# # Coletando os dados das estações BP

# %%
ev_list = []
ev_listS = []
#for root, dirs, files in os.walk('/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/syngine_filtered_PP/a_1/'):
for root, dirs, files in os.walk('/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/rede_BB/event_data_PP_selected/a_05/'):
    for datafile in files:
        if datafile.endswith('.eqr'):
            ev_list.append(os.path.join(root, datafile))
ev_listS = sorted(ev_list)

# %%
ev = obspy.Stream()
for i,j in enumerate(ev_listS):
    ev += obspy.read(j)

# %%
event_DD = []
event_MM = []
event_YYYY = []
event_hh = []
event_mm = []
event_julday = []
event_depth = []
event_lat = []
event_long = []
event_dist = []
event_gcarc = []
event_sta = []
event_channel = []
event_ray = []
sta_lat = []
sta_long = []
sta_channel = []
sta_data = []
sta_time = []
event_starttime = []
event_endtime = []


for i,j in enumerate(ev):
    if j.stats.sac.gcarc > 30:
            event_time = (j.stats.starttime)
            event_starttime.append(j.stats.starttime)
            event_endtime.append(j.stats.endtime)
            event_DD.append("{0:02.0f}".format(event_time.day))
            event_MM.append("{0:02.0f}".format(event_time.month))
            event_YYYY.append(event_time.year)
            event_hh.append("{0:02.0f}".format(event_time.hour))
            event_mm.append("{0:02.0f}".format(event_time.minute))
            event_julday.append(event_time.julday)
            event_depth.append(j.stats.sac.evdp)
            event_lat.append(j.stats.sac.evla)
            event_long.append(j.stats.sac.evlo)
            event_dist.append(j.stats.sac.dist)
            event_gcarc.append(j.stats.sac.gcarc)
            event_sta.append(j.stats.station)
            event_ray.append(j.stats.sac.user8)
            sta_lat.append(j.stats.sac.stla)
            sta_long.append(j.stats.sac.stlo)
            sta_data.append(j.data)
            sta_time.append(j.times())

# %%
fig=plt.figure(figsize=(20,10))


project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='cyl',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-170.,
            llcrnrlat=-85.,urcrnrlon=65.,urcrnrlat=85.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(event_long,event_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '*',markersize=msize,markeredgecolor='k',markerfacecolor='y')

for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for evlon_0, evlat_0, evlon_c,evlat_c in zip(sta_long,sta_lat,event_long,event_lat):
    m.drawgreatcircle(evlon_0, evlat_0, evlon_c,evlat_c,linewidth=2,color='grey',alpha=0.1)

    
m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='k',zorder=10)
m.drawmeridians(np.arange(0, 360, 20),color='lightgrey')
m.drawparallels(np.arange(-90, 90, 10),color='lightgrey')

sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')

plt.title('Events Selected Locataion')
# Out:
# Text(0.5,1,'Events Selected Locataion')

# %% [markdown]
# ## Criando um modelo de terra através do obspy.taup.taup_create.build_taup_model

# %%
obspy.taup.taup_create.build_taup_model('/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/velocity_model/iasp91_10.tvel',output_folder='/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/velocity_model/')
# Out:
# Building obspy.taup model for '/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/velocity_model/iasp91_10.tvel' ...

# %%
model_10_km = TauPyModel(model='/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/velocity_model/iasp91_10.npz')

# %% [markdown]
# dtype=[('top_depth', '<f8'), ('bot_depth', '<f8'), ('top_p_velocity', '<f8'), ('bot_p_velocity', '<f8'), ('top_s_velocity', '<f8'), ('bot_s_velocity', '<f8'), ('top_density', '<f8'), ('bot_density', '<f8'), ('top_qp', '<f8'), ('bot_qp', '<f8'), ('top_qs', '<f8'), ('bot_qs', '<f8')])

# %%
top_depth = []
bot_depth = []
top_p_velocity = []
bot_p_velocity = []
top_s_velocity = []
bot_s_velocity = []
top_density = []
bot_density = []
top_qp = []
bot_qp = []
top_qs = []
bot_qs = []
for i,j in enumerate(model_10_km.model.s_mod.v_mod.layers):
    top_depth.append(j[0])
    bot_depth.append(j[1])
    top_p_velocity.append(j[2])
    bot_p_velocity.append(j[3])
    top_s_velocity.append(j[4])
    bot_s_velocity.append(j[5])
    top_density.append(j[6])
    bot_density.append(j[7])
    top_qp.append(j[8])
    bot_qp.append(j[9])
    top_qs.append(j[10])
    bot_qs.append(j[11])

# %%
plt.figure(figsize=(5,10))
plt.title('IASP91 Earth Model 10 km thick')
plt.plot(top_p_velocity,top_depth,'b',label='P Velocity km/s')
plt.plot(top_s_velocity,top_depth,'g',label='S Velocity km/s')
plt.plot(top_density,top_depth,'r',label='Density')
plt.legend()
plt.ylim(6400,0)
plt.xlim(-0.5,14)
# Out:
# (-0.5, 14)

# %%
radius = model_10_km.model.radius_of_planet
camadas = model_10_km.model.s_mod.v_mod.get_discontinuity_depths()

# %% [markdown]
# # Calculando os caminhos dos raios para os eventos das estações BP

# %%
arrivals = []
for i,j in enumerate(event_depth):
    arrivals.append(model_10_km.get_ray_paths_geo(
                                    source_depth_in_km=j, source_latitude_in_deg=event_lat[i], 
                                    source_longitude_in_deg=event_long[i], receiver_latitude_in_deg=sta_lat[i], 
                                    receiver_longitude_in_deg=sta_long[i], phase_list=["P"]))

# %%
lat_lst = [[]]*len(arrivals)
long_lst = [[]]*len(arrivals)
depth_lst = [[]]*len(arrivals)
for i,j in enumerate(arrivals):
    lat_lst.append([l.path['lat'] for k,l in enumerate(j)])
    long_lst.append([l.path['lon'] for k,l in enumerate(j)])
    depth_lst.append([l.path['depth'] for k,l in enumerate(j)])

# %%
fig, ax = plt.subplots()

for i,j in enumerate(arrivals):
    [ax.plot(l.path['lon'],l.path['lat'],'k-') for k,l in enumerate(j)]
for i,j in enumerate(event_lat):
    ax.plot(event_long[i],j, color='yellow', marker='*', markersize=10,markeredgecolor='k') 
    ax.plot(sta_long[i],sta_lat[i], color='w', marker='^', markersize=15,markeredgecolor='k')

# %%
fig, ax = plt.subplots()
for i,j in enumerate(arrivals):
    [ax.plot(l.path['lat'],l.path['depth'],'k--',alpha=0.2) for k,l in enumerate(j)]

for i,j in enumerate(event_depth):
    ax.plot(event_lat[i],j,'y*') 
    ax.plot(sta_lat[i],-10,'k^') 
ax.hlines(410,-90,90)
ax.hlines(40,-90,90)
ax.hlines(660,-90,90)
ax.set_ylim(radius,-100)
ax.set_xlim(-90,90)
# Out:
# (-90, 90)

# %%
dist_event = [[]]*len(arrivals)
depth = [[]]*len(arrivals)
lat = [[]]*len(arrivals)
long = [[]]*len(arrivals)
time = [[]]*len(arrivals)


for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        dist_event[i] = l.path['dist'][int(len(l.path['dist'])/2):]
        depth[i] = l.path['depth'][int(len(l.path['depth'])/2):]
        lat[i] = l.path['lat'][int(len(l.path['lat'])/2):]
        long[i] = l.path['lon'][int(len(l.path['lon'])/2):]
        time[i] = l.path['time'][int(len(l.path['lon'])/2):]

# %%
camadas_terra_10_km = np.arange(0,810,10)

# %%
fig, ax = plt.subplots(figsize=(10, 15))



for i,j in enumerate(depth):
    ax.plot(long[i],j,'k--',lw=0.5,alpha=0.5)

    
for i,j in enumerate(camadas_terra_10_km):
    ax.hlines(j,-55,-35,lw=0.5,alpha=0.5)
#for i,j in enumerate(arrivals):
#    [ax.plot(l.path['dist'],l.path['depth'],'k--',lw=0.5,alpha=0.5) for k,l in enumerate(j)]
for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        [ax.plot(l.path['lon'][x],l.path['depth'][x],marker='+', markersize=5,markeredgecolor='orange') for x,c in enumerate(l.path['depth']) if c == 35]
        [ax.plot(l.path['lon'][x],l.path['depth'][x],marker='+', markersize=5,markeredgecolor='g') for x,c in enumerate(l.path['depth']) if c == 410]
        [ax.plot(l.path['lon'][x],l.path['depth'][x],marker='+', markersize=5,markeredgecolor='b') for x,c in enumerate(l.path['depth']) if c == 660]
for i,j in enumerate(event_depth):
    #ax.plot(event_long[i],j, color='yellow', marker='*', markersize=5,markeredgecolor='k') 
    ax.plot(sta_long[i],-20, color='w', marker='^', markersize=15,markeredgecolor='k')
    #ax.text(sta_long[i]-0.3,-100,event_sta[i])

ax.hlines(0,-55,-35,colors='k',linestyles='solid')
ax.hlines(40,-55,-35,colors='orange',linestyles='dashed',label='Moho')
ax.hlines(410,-55,-35,colors='g',linestyles='dashed',label='410 km')
ax.hlines(660,-55,-35,colors='b',linestyles='dashed',label='660 km')

ax.set_ylim(1000,-200)
ax.set_ylabel('Depth (km)')
ax.set_xlabel('Longitude')

ax.legend(loc=0,edgecolor='w',fancybox=True)
ax.set_xlim(-55,-35)
fig.savefig('/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/ray_path.png',dpi=300)

# %% [markdown]
# # Selecionando a profundidade máxima e mínima da migração:

# %%
depth_mig_min = 300
depth_mig_max = 700

# %%
lon_10_km = []
lat_10_km = []
depth_10_km = []
time_10_km  = []
for i,j in enumerate(depth):
    lat_10_km.append([lat[i][np.where(j == l)] for k,l in enumerate(camadas_terra_10_km)  if len(lat[i][np.where(j == l)]) > 0 ])
    lon_10_km.append([long[i][np.where(j == l)] for k,l in enumerate(camadas_terra_10_km)  if len(long[i][np.where(j == l)]) > 0 ])
    depth_10_km.append([j[np.where(j == l)] for k,l in enumerate(camadas_terra_10_km)   if len(j[np.where(j == l)]) > 0])
    time_10_km.append([max(time[i]) - time[i][np.where(j == l)][0] for k,l in enumerate(camadas_terra_10_km)  if len(time[i][np.where(j == l)]) > 0 ])

# %%
fig, ax = plt.subplots(figsize=(10, 15))



for i,j in enumerate(depth_10_km):
    ax.plot(lon_10_km[i],j,'+',markersize=5,markeredgecolor='k')
for i,j in enumerate(depth):
    ax.plot(long[i],j,'k--',lw=0.1,alpha=0.9)

    
for i,j in enumerate(camadas_terra_10_km):
    ax.hlines(j,-55,-35,lw=0.5,alpha=0.5)
    
ax.hlines(depth_mig_min,-55,-35, colors='r', lw=4,linestyles='dashed')    
ax.hlines(depth_mig_max,-55,-35, colors='r', lw=4,linestyles='dashed')    


for i,j in enumerate(event_depth):
    #ax.plot(event_long[i],j, color='yellow', marker='*', markersize=5,markeredgecolor='k') 
    ax.plot(sta_long[i],-10, color='w', marker='^', markersize=15,markeredgecolor='k')
    #ax.text(sta_long[i]-0.3,-100,event_sta[i])

ax.hlines(0,-55,-35,colors='k', lw=2,linestyles='solid')
ax.hlines(40,-55,-35,colors='orange', lw=2,linestyles='dashed',label='Moho')
ax.hlines(410,-55,-35,colors='g', lw=2,linestyles='dashed',label='410 km')
ax.hlines(660,-55,-35,colors='b', lw=2,linestyles='dashed',label='660 km')

ax.set_ylim(800,-90)
ax.set_ylabel('Depth (km)')
ax.set_xlabel('Longitude')

ax.legend(loc=0,edgecolor='w',fancybox=True)
ax.set_xlim(-55,-35)
fig.savefig('/home/diogo/dados_doutorado/parnaiba_basin/RF_migration/redeBP-BB/transition_zone/ray_path_10_thick.png',dpi=300)

# %% [markdown]
# # Migrando os dados de tempo para profundidade

# %%
time_RF = [[]]*len(arrivals)
depth_RF = [[]]*len(arrivals)
long_RF = [[]]*len(arrivals)
lat_RF = [[]]*len(arrivals)

for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        time_fim = l.path['time'][int(len(l.path['time'])/2):][-1]
        time_a = time_fim - l.path['time'][int(len(l.path['time'])/2):]
        depth_a = l.path['depth'][int(len(l.path['depth'])/2):]
        lat_a = l.path['lat'][int(len(l.path['lat'])/2):]
        long_a = l.path['lon'][int(len(l.path['lon'])/2):]

        time_RF[i] = time_a[::-1]
        depth_RF[i] = depth_a[::-1]
        long_RF[i] = long_a[::-1]
        lat_RF[i] = lat_a[::-1]

# %%
RF_amplitude = []

for i,j in enumerate(time_10_km):
    sta_t = [round(l,1) for k,l in enumerate(sta_time[i])]
    RF_t = [round(l,1) for k,l in enumerate(j)]
    RF_amplitude.append([sta_data[i][sta_t.index(l)] for k,l in enumerate(RF_t)])

# %%
RF_amplitude_ok = []
for i,j in enumerate(RF_amplitude):
    if len(j) > 80:
        RF_amplitude_ok.append(j[:80])
    elif len(j) < 80:
        tamanho = 80-len(j)
        zero_list = [0] * tamanho
        RF_amplitude_ok.append(j+zero_list)
    else:
        RF_amplitude_ok.append(j)

# %% [markdown]
# # Piercing Points - profundidade mínima da migração

# %%
pp_depth_mig_min_lat = [[]]*len(arrivals)
pp_depth_mig_min_long = [[]]*len(arrivals)

for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]

        
        depth_closest = min(depth, key=lambda x:abs(x-depth_mig_min))
    
        pp_depth_mig_min_lat[i] = [lat[x] for x,c in enumerate(depth) if c == depth_closest][0]
        pp_depth_mig_min_long[i] = [long[x] for x,c in enumerate(depth) if c == depth_closest][0]

# %% [markdown]
# # Piercing Points - profundidade máxima da migração

# %%
pp_depth_mig_max_lat = [[]]*len(arrivals)
pp_depth_mig_max_long = [[]]*len(arrivals)

for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]

        depth_closest = min(depth, key=lambda x:abs(x-depth_mig_max))
        
        pp_depth_mig_max_lat[i] = [lat[x] for x,c in enumerate(depth) if c == depth_closest][0]
        pp_depth_mig_max_long[i] = [long[x] for x,c in enumerate(depth) if c == depth_closest][0]

# %%
fig=plt.figure(figsize=(20,10))



project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='eqdc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-55.,
            llcrnrlat=-14.,urcrnrlon=-35.,urcrnrlat=2.)

sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_depth_mig_min_long,pp_depth_mig_min_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')
    
for lon, lat in zip(pp_depth_mig_max_long,pp_depth_mig_max_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='b',markerfacecolor='k')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 3),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 3),color='lightgrey',labels=[True,True,True,True])


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')

plt.title('Piercing Points - Filter between '+str(depth_mig_min)+' km and '+str(depth_mig_max)+' km', y=1.08)

# %% [markdown]
# # Piercing Points - 35 km - MOHO

# %%
pp_35_lat =  [[]]*len(arrivals)
pp_35_long  = [[]]*len(arrivals)
for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        time = l.path['time'][int(len(l.path['time'])/2):]
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]

        pp_35_lat[i] = [lat[x] for x,c in enumerate(depth) if c == 35][0]
        pp_35_long[i] = [long[x] for x,c in enumerate(depth) if c == 35][0]

# %%
fig=plt.figure(figsize=(20,10))



project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='eqdc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-50.,
            llcrnrlat=-12.,urcrnrlon=-40.,urcrnrlat=0.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_35_long,pp_35_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 3),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 3),color='lightgrey',labels=[True,True,True,True])


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')

plt.title('Piercing Points - 40 km', y=1.08)

# %% [markdown]
# # Piercing Points -410 km

# %%
pp_410_lat  = [[]]*len(arrivals)
pp_410_long  = [[]]*len(arrivals)
for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]

        pp_410_lat[i] = [lat[x] for x,c in enumerate(depth) if c == 410][0]
        pp_410_long[i] = [long[x] for x,c in enumerate(depth) if c == 410][0]

# %%
fig=plt.figure(figsize=(20,10))



project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='eqdc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-55.,
            llcrnrlat=-12.,urcrnrlon=-35.,urcrnrlat=1.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_410_long,pp_410_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')

plt.title('Piercing Points - 410 km', y=1.08)

# %% [markdown]
# # Piercing Points -660 km

# %%
pp_660_lat  = [[]]*len(arrivals)
pp_660_long  = [[]]*len(arrivals)
for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]
        for x,c in enumerate(depth):
            if c == 660:
                pp_660_lat[i] = lat[x]
                pp_660_long[i] = long[x]

# %%
fig=plt.figure(figsize=(20,10))


project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='eqdc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-55.,
            llcrnrlat=-14.,urcrnrlon=-35.,urcrnrlat=2.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_660_long,pp_660_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])

sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)

        m.plot(x, y, '-', lw=3, color='k')

plt.title('Piercing Points - 660 km', y=1.08)

# %% [markdown]
# # Piercing Points - 510  km

# %%
pp_510_lat  = [[]]*len(arrivals)
pp_510_long  = [[]]*len(arrivals)
for i,j in enumerate(arrivals):
    for k,l in enumerate(j):
        depth = l.path['depth'][int(len(l.path['depth'])/2):]
        lat = l.path['lat'][int(len(l.path['lat'])/2):]
        long = l.path['lon'][int(len(l.path['lon'])/2):]
        for x,c in enumerate(depth):
            if c == 510:
                pp_510_lat[i] = lat[x]
                pp_510_long[i] = long[x]

# %%
fig=plt.figure(figsize=(20,10))


project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='eqdc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-55.,
            llcrnrlat=-14.,urcrnrlon=-35.,urcrnrlat=2.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_510_long,pp_510_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])

sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)

        m.plot(x, y, '-', lw=3, color='k')

plt.title('Piercing Points - 510 km', y=1.08)

# %% [markdown]
# # Criando o GRID

# %%
area_lat = [-15, 0]
area_lon = [-55, -35]

# %%
area = (area_lon[0], area_lon[1], area_lat[0], area_lat[1])

shape = (abs(abs(area_lon[1]) - abs(area_lon[0]))*3, abs(abs(area_lat[1]) - abs(area_lat[0]))*3)

# First, we need to know the real data at the grid points
grdx, grdy = gridder.regular(area, shape)

# %%
fig=plt.figure(figsize=(20,10))



project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='merc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-60.,
            llcrnrlat=-20.,urcrnrlon=-30.,urcrnrlat=5.)


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')


for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

for lon, lat in zip(pp_35_long,pp_35_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='g',markerfacecolor='k')
    
for lon, lat in zip(pp_410_long,pp_410_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')
    
for lon, lat in zip(pp_510_long,pp_510_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='m',markerfacecolor='k')

for lon, lat in zip(pp_660_long,pp_660_lat):
    x,y = m(lon, lat)
    msize = 3
    m.plot(x, y, '+',markersize=msize,markeredgecolor='b',markerfacecolor='k')
    
for lon, lat in zip(grdx,grdy):
    x,y = m(lon, lat)
    msize = 5
    m.plot(x, y, '.',markersize=msize,markeredgecolor='k',markerfacecolor="None")

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')

plt.title('BIN DATA', y=1.08)

# %% [markdown]
# # Filtrando os pontos do GRID

# %%
dist_pp_grid_min = [[]]*len(grdx)
for i,j in enumerate(grdx):
    dist_pp_grid_min[i] = [np.sqrt((j - pp_depth_mig_min_long[k])**2 + (grdy[i] - l)**2) for k,l in enumerate(pp_depth_mig_min_lat)]
    
dist_pp_grid_max = [[]]*len(grdx)
for i,j in enumerate(grdx):
    dist_pp_grid_max[i] = [np.sqrt((j - pp_depth_mig_max_long[k])**2 + (grdy[i] - l)**2) for k,l in enumerate(pp_depth_mig_max_lat)]

# %%
dist_grid_piercing_points = 2
number_piercing_points_per_bin = 3 

grid_sel_min = []
grid_sel_min_data = []
for i,j in enumerate(dist_pp_grid_min):
    vect_j = np.array(j) 
    indices = vect_j.argsort()
    if vect_j[indices[number_piercing_points_per_bin]] < dist_grid_piercing_points:
        grid_sel_min.append((grdx[i],grdy[i]))
        
grid_sel_max = []
grid_sel_min_data = []

for i,j in enumerate(dist_pp_grid_max):
    vect_j = np.array(j) 
    indices = vect_j.argsort()
    if vect_j[indices[number_piercing_points_per_bin]] < dist_grid_piercing_points:
        grid_sel_max.append((grdx[i],grdy[i]))

# %%
grid_sel = grid_sel_min+grid_sel_max

# %%
grid_selected = set(map(tuple,grid_sel))

# %%
grid_sel_x = []
grid_sel_y = []
for i,j in enumerate(grid_selected):
    grid_sel_x.append(j[0])
    grid_sel_y.append(j[1])

# %%
fig=plt.figure(figsize=(20,10))



project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='merc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-60.,
            llcrnrlat=-20.,urcrnrlon=-30.,urcrnrlat=5.)

sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=0.75, color='k')

for lon, lat in zip(grdx,grdy):
    x,y = m(lon, lat)
    msize = 0.5
    l6, = m.plot(x, y, 'o',markersize=msize,markeredgecolor='k',markerfacecolor="None")

for lon, lat in zip(grid_sel_x, grid_sel_y):
    x,y = m(lon, lat)
    msize = 4
    l4, = m.plot(x, y, 'o',markersize=msize,markeredgecolor='k',markerfacecolor="None")
    
for lon, lat in zip(pp_depth_mig_min_long,pp_depth_mig_min_lat):
    x,y = m(lon, lat)
    msize = 5
    l2, = m.plot(x, y, '+',markersize=msize,markeredgecolor='r',markerfacecolor='k')
    
for lon, lat in zip(pp_depth_mig_max_long,pp_depth_mig_max_lat):
    x,y = m(lon, lat)
    msize = 5
    l3, = m.plot(x, y, '+',markersize=msize,markeredgecolor='b',markerfacecolor='k')
    
    
for lon, lat in zip(pp_510_long,pp_510_lat):
    x,y = m(lon, lat)
    msize = 3
    l5, = m.plot(x, y, '+',markersize=msize,markeredgecolor='m',markerfacecolor='k')

for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    l1, = m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

m.fillcontinents(color='whitesmoke',lake_color=None)
m.drawcoastlines(color='dimgray',zorder=10)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        x, y = zip(*points)
        m.plot(x, y, '-', lw=3, color='k')
        
label=['Stations','Piercing Points min','Piercing Points max','Filtered Grid Points','510 km Piercing Points','Grid Points']
plt.legend([l1,l2,l3,l4,l5,l6],label,scatterpoints=1, frameon=True,labelspacing=1, loc='upper right',facecolor='w')

#plt.title('BIN DATA', y=1.08)

# %% [markdown]
# # Empilhando os dados nos pontos do GRID filtrado

# %%
dist_between_grid_piercing_points = 1.5
dados_grid_lat = pp_410_lat
dados_grid_lon = pp_410_long


RF_data_raw = [[]]*len(grid_sel_x)
RF_RAY_raw = [[]]*len(grid_sel_x)

for i,j in enumerate(grid_sel_x):
    RF_data_raw[i] = [np.array(RF_amplitude_ok[k])  for k,l in enumerate(pp_410_lat) if np.sqrt((j - pp_410_long[k])**2 + (grid_sel_y[i] - l)**2) < dist_between_grid_piercing_points]
    RF_RAY_raw[i] = [event_ray[k]  for k,l in enumerate(pp_410_lat) if np.sqrt((j - pp_410_long[k])**2 + (grid_sel_y[i] - l)**2) < dist_between_grid_piercing_points]

# %%
RF_stacking = []
len_RF_stacking = []
RF_ray_stacking = []

for i,j in enumerate(RF_data_raw):
    if len(j) != 0:
        RF_stacking.append(sum(j)/len(j))
        len_RF_stacking.append(len(j))
        RF_ray_stacking.append(sum(RF_RAY_raw[i])/len(j))
    else:
        RF_stacking.append([])
        len_RF_stacking.append(0)
        RF_ray_stacking.append(0)

# %%
fig=plt.figure(figsize=(20,10))

project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='merc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-60.,
            llcrnrlat=-20.,urcrnrlon=-30.,urcrnrlat=5.)

lats = grid_sel_y
lons = grid_sel_x
RF_number = len_RF_stacking
x, y = m(lons,lats)
sc = m.scatter(x,y,40,RF_number,cmap='hot',marker='o')
plt.colorbar(sc,label='Total of Receiver Functions per bin')


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=2, color='w')

for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    l1, = m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

m.fillcontinents(color='whitesmoke',lake_color=None,zorder=0)
m.drawcoastlines(color='dimgray',zorder=1)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])

plt.legend([l1,sc],['Stations','Filtered Grid Points'],scatterpoints=1, frameon=True,labelspacing=1, loc='upper right',facecolor='w')
plt.title('BIN DATA', y=1.08)

# %% [markdown]
# # Criando perfis para o GRID

# %% [markdown]
# ## Perfil A-B

# %%
AB_lon_line = [-55,-35]
AB_lat_line = [-4.7,-4.7]

# %%
AB_lon = np.linspace(AB_lon_line[0],AB_lon_line[1],abs(abs(AB_lon_line[1])-abs(AB_lon_line[0]))*3)
AB_lat = np.linspace(AB_lat_line[0],AB_lat_line[1],abs(abs(AB_lon_line[1])-abs(AB_lon_line[0]))*3)

# %%
fig=plt.figure(figsize=(20,10))

project_Lat = -5
project_Lon = -45

m = Basemap(resolution='l',projection='merc',lat_0=project_Lat, lon_0=project_Lon,llcrnrlon=-60.,
            llcrnrlat=-20.,urcrnrlon=-30.,urcrnrlat=5.)

xA, yA = m(AB_lon_line[0],AB_lat_line[0])
plt.text(xA-100000, yA, 'A',fontsize=20)

xB, yB = m(AB_lon_line[1],AB_lat_line[1])
plt.text(xB+40000, yB, 'B',fontsize=20)

m.drawgreatcircle(AB_lon_line[0],AB_lat_line[0],AB_lon_line[1],AB_lat_line[1],linewidth=5,color='r')

for lon, lat in zip(AB_lon,AB_lat):
    x,y = m(lon, lat)
    msize = 10
    #l1, = m.plot(x, y, 'o',markersize=msize,markeredgecolor='k',markerfacecolor='y')

lats = grid_sel_y
lons = grid_sel_x
RF_number = len_RF_stacking
x, y = m(lons,lats)
sc = m.scatter(x,y,20,RF_number,cmap='hot',marker='o')
plt.colorbar(sc,label='Total of Receiver Functions per bin')


sf = shapefile.Reader('/home/diogo/dados_doutorado/parnaiba_basin/SIG_dados/shapes/bacia_parnaiba/bacia_parnaiba.shp')
for shape in sf.shapes():
    # adding polygon(s)
    parts = list(shape.parts) + [len(shape.points)]
    partlims = zip(parts[:-1], parts[1:])
    for i1, i2 in partlims:
        points = shape.points[i1:i2]
        lon, lat = zip(*points)
        x,y = m(lon, lat)
        m.plot(x, y, '-', lw=2, color='k')

for lon, lat in zip(sta_long,sta_lat):
    x,y = m(lon, lat)
    msize = 10
    l1, = m.plot(x, y, '^',markersize=msize,markeredgecolor='k',markerfacecolor='grey')

m.fillcontinents(color='whitesmoke',lake_color='#46bcec',zorder=0)
m.drawcoastlines(color='dimgray',zorder=1)
m.drawmeridians(np.arange(0, 360, 5),color='lightgrey',labels=[True,True,True,True])
m.drawparallels(np.arange(-90, 90, 5),color='lightgrey',labels=[True,True,True,True])

plt.legend([l1,sc],['Stations','Grid Points'],scatterpoints=1, frameon=True,labelspacing=1, loc='upper right',facecolor='w')
plt.title('BIN DATA and Profile', y=1.08)

# %%
RF_data_profile = []
RF_RAY_profile = []

for i,j in enumerate(AB_lon):
    dist = [np.sqrt((j - grid_sel_x[k])**2 + (AB_lat[i] - l)**2)  for k,l in enumerate(grid_sel_y)]
    RF_data_profile.append(RF_stacking[dist.index(min(dist))])
    RF_RAY_profile.append(RF_ray_stacking[dist.index(min(dist))])

# %%
RF_data_profile_stacking = []
RF_RAY_profile_stacking = []
for i,j in enumerate(RF_data_profile):
    if len(j) != 0:
        RF_data_profile_stacking.append(j)
        RF_RAY_profile_stacking.append(RF_RAY_profile[i])

    #else:
        #RF_data_profile_stacking.append(np.zeros_like(sta_time[0]))
        #RF_RAY_profile_stacking.append(0)

# %%
Z_real = np.array(RF_data_profile_stacking)

# %%
camadas_terra_10_km[:80]

# %%
factor = 50
plt.figure(figsize = (15,10))
for i, j in enumerate(RF_data_profile_stacking): 
    plt.text(-15,i/factor,"{0:.3f}".format(RF_RAY_profile_stacking[i]))
    plt.plot(camadas_terra_10_km[:80],i/factor+j,'k',linewidth=0.5)
    plt.fill_between(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)>=i/factor, facecolor='black',alpha=0.6, interpolate=True)
    plt.fill_between(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)<=i/factor, facecolor='gray',alpha=0.6, interpolate=True)
    #plt.title('Funcoes do Receptor - a = 0.5 - user5 > 80 - '+STA[z])
    #plt.xlim(-5,260)
    plt.yticks([])
    ax.grid(True)

    #plt.ylim(-0.1,0.4)

# %%
factor = 50
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#majorLocatorX = MultipleLocator(300)
majorLocatorY = MultipleLocator(50)
minorLocatorY = MultipleLocator(10)
#minorLocatorX = MultipleLocator(10)


for i, j in enumerate(RF_data_profile_stacking): 
    #plt.plot(time_real-10,i/factor+j,'k',linewidth=0.5)
    ax.text(i/factor,-15,"{0:.2f}".format(RF_RAY_profile_stacking[i]),rotation=45)
    ax.plot(i/factor+j,camadas_terra_10_km[:80],'k',linewidth=0.5)
    ax.yaxis.set_major_locator(majorLocatorY)
    #ax.xaxis.set_minor_locator(minorLocatorX)
    ax.yaxis.set_minor_locator(minorLocatorY)
    ax.fill_betweenx(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)>=i/factor, facecolor='black',alpha=0.6, interpolate=True)
    ax.fill_betweenx(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)<=i/factor, facecolor='gray',alpha=0.6, interpolate=True)
    #plt.title('Funcoes do Receptor - a = 0.5 - user5 > 80 - '+STA[z])
    ax.set_xticks([])
    ax.grid(True)

    ax.set_ylim(800,0)

# %% [markdown]
# # Move-Out  Corrections
#
# ### The use of velocity spectrum for stacking receiver functions and  imaging upper mantle discontinuities
#
# ##### H. Gurrola, J. B. Minster and T. Owens
#
# ##### Geophys. J . In<. (1994) 117,427-440

# %% [markdown]
# ## Reflection moveout (e.g. Sheriff & Geldart 1982; Yilmaz 1987)

# %% [markdown]
# #### Ps reflection calculus

# %%
IASP91_depth = top_depth
IASP01_svel = top_s_velocity
IASP01_pvel = top_p_velocity

# %%
delta_T_Ps = [[]]*len(IASP91_depth)
for i,j in enumerate(IASP91_depth):
    delta_T_Ps0 = j*(np.sqrt(np.power(IASP01_svel[i],-2)) - np.sqrt(np.power(IASP01_pvel[i],-2)))
    Rv = IASP01_pvel[i]/IASP01_svel[i]
    delta_T_Ps[i] = [((Rv*delta_T_Ps0)/(Rv-1))*(np.sqrt(1 - np.power(l,2)*np.power(IASP01_svel[i],2)) - np.sqrt(np.power(Rv,-2) - np.power(l,2)*np.power(IASP01_svel[i],2))) for l in RF_RAY_profile_stacking]

# %%
for i,j in enumerate(delta_T_Ps):
    plt.plot(j,'ok')

#plt.ylim(1400,0)

# %%
factor = 50
plt.figure(figsize = (15,10))
for i, j in enumerate(RF_data_profile_stacking): 
    plt.text(-15,i/factor,"{0:.3f}".format(RF_RAY_profile_stacking[i]))
    plt.plot(camadas_terra_10_km[:80],i/factor+j,'k',linewidth=0.5)
    plt.fill_between(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)>=i/factor, facecolor='black',alpha=0.6, interpolate=True)
    plt.fill_between(camadas_terra_10_km[:80],i/factor+j,i/factor,where=(i/factor+j)<=i/factor, facecolor='gray',alpha=0.6, interpolate=True)
    #plt.title('Funcoes do Receptor - a = 0.5 - user5 > 80 - '+STA[z])
    #plt.xlim(-5,260)
    plt.yticks([])
    ax.grid(True)

    #plt.ylim(-0.1,0.4)

# %% [markdown]
# #### P2p1s reflection calculus

# %%
delta_T_Pps = [[]]*len(IASP91_depth)
for i,j in enumerate(IASP91_depth):
    delta_T_Pps0 = j*(np.sqrt(np.power(IASP01_svel[i],-2)) + np.sqrt(np.power(IASP01_pvel[i],-2)))
    Rv = IASP01_pvel[i]/IASP01_svel[i]
    delta_T_Pps[i] = [((Rv*delta_T_Pps0)/(Rv+1))*(np.sqrt(1 - np.power(l,2)*np.power(IASP01_svel[i],2)) + np.sqrt(np.power(Rv,-2) - np.power(l,2)*np.power(IASP01_svel[i],2))) for l in RF_RAY_profile_stacking]

# %%
factor = 100
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

#majorLocatorX = MultipleLocator(300)
majorLocatorY = MultipleLocator(10)
minorLocatorY = MultipleLocator(20)
#minorLocatorX = MultipleLocator(10)


for i, j in enumerate(RF_data_profile_stacking): 
    ax.text(i/factor,-15,"{0:.2f}".format(RF_RAY_profile_stacking[i]),rotation=45)
    ax.plot(i/factor,delta_T_Ps[8][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    ax.plot(i/factor,delta_T_Ps[82][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    ax.plot(i/factor,delta_T_Ps[132][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    ax.plot(i/factor,delta_T_Pps[8][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    ax.plot(i/factor,delta_T_Pps[82][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    ax.plot(i/factor,delta_T_Pps[132][i],'.k',markersize=10,markeredgecolor='k',markerfacecolor='None')
    #plt.plot(time_real-10,i/factor+j,'k',linewidth=0.5)
    ax.plot(i/factor+j,time_real-10,'k',linewidth=0.5)
    ax.yaxis.set_major_locator(majorLocatorY)
    #ax.xaxis.set_minor_locator(minorLocatorX)
    ax.yaxis.set_minor_locator(minorLocatorY)
    ax.fill_betweenx(time_real-10,i/factor+j,i/factor,where=(i/factor+j)>=i/factor, facecolor='black',alpha=0.6, interpolate=True)
    ax.fill_betweenx(time_real-10,i/factor+j,i/factor,where=(i/factor+j)<=i/factor, facecolor='gray',alpha=0.6, interpolate=True)
    #plt.title('Funcoes do Receptor - a = 0.5 - user5 > 80 - '+STA[z])
    ax.set_xlim(-0.05,0.4)
    ax.grid(True)

    ax.set_ylim(220,-5)
